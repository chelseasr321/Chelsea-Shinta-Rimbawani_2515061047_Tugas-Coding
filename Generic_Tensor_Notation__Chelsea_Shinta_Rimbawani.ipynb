# %% [markdown]
# Soal 1 :
# jelaskan tentang perintah ini :
# images_pt = torch.zeros([32, 28, 28, 3])

# %%
import torch
import tensorflow as tf

# %%
images_pt = torch.zeros([32, 28, 28, 3]) # bertujuan untuk membuat sebuah tensor baru berisi angka nol.
