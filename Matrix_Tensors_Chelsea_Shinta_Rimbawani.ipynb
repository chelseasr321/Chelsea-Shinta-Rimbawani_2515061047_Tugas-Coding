# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
x = np.array([[25, 15, 61], [47, 23, 4]])
x # buat matrix X berukuran 2x3 menggunakan numpy
# Out:
# array([[25, 15, 61],
#        [47, 23,  4]])

# %%
x.shape # tampilkan ukuran dari matrix x
# Out:
# (2, 3)

# %%
x[:,0] # tampilkan seluruh elemen dari kolom pertama dari matrix x
# Out:
# array([25, 47])

# %%
x[:,1] # tampilkan seluruh elemen dari baris kedua dari matrix x
# Out:
# array([15, 23])

# %% [markdown]
# Soal 2

# %% [markdown]
# ulangi soal nomor 1 menggunakan pytorch

# %%
import torch

# %%
x_pt = torch.tensor([[25, 15, 61], [47, 23, 4]])
x_pt

# %%
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
x_pt[:,0]
# Out:
# tensor([25, 47])

# %%
x_pt[:,1]
# Out:
# tensor([15, 23])

# %% [markdown]
# ulangi soal nomor 1 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable([[25, 15, 61], [47, 23, 4]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[25, 15, 61],
#        [47, 23,  4]], dtype=int32)>

# %%
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
x_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([25, 47], dtype=int32)>

# %%
x_tf[:,1]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([15, 23], dtype=int32)>
