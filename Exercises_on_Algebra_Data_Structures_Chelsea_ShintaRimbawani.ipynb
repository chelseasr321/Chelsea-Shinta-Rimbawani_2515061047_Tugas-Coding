# %% [markdown]
# Soal 1 : selesaikan soal![Screenshot 2026-04-09 190756.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
x = np.array ([[25],
               [ 2],
               [ -3],
               [-23]])
x # masukkan vector
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
x_t = x.T
x_t # transpose vector
# Out:
# array([[ 25,   2,  -3, -23]])
