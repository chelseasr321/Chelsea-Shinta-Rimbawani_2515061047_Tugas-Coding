# %% [markdown]
# Soal 1

# %%
import numpy as np

# %%
x = np.array([25,61,47]) # buat vector x dengan ukuran 3x1
x
# Out:
# array([25, 61, 47])

# %%
len(x) # Hitung panjang vector x
# Out:
# 3

# %%
x.shape # Tampilkan ukuran vector x
# Out:
# (3,)

# %%
type(x) # Tampilkan tipe data dari vector
# Out:
# numpy.ndarray

# %%
x[0] # Akses elemen pertma dari vector x
# Out:
# np.int64(25)

# %%
type (x[0]) # Tampilkan tipe data elemen pertama dari vector x
# Out:
# numpy.int64

# %% [markdown]
# Soal 2

# %%
x_t = x.T # lakukan transpose pada vector x dan simpan pada variabel x_t
x_t
# Out:
# array([25, 61, 47])

# %%
x_t.shape # tampilkan ukuran dari vector x_t
# Out:
# (3,)

# %%
y = np.array([[25, 61, 47]]) # lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y
y_t
# Out:
# array([[25, 61, 47]])

# %%
y_t.shape # tampilkan ukuran dari vector x_t
# Out:
# (1, 3)

# %% [markdown]
# Soal 3 lakukan soal nomor 2 menggunakan pytorch dan tensorflow

# %%
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([25, 61, 47])
x_pt
# Out:
# tensor([25, 61, 47])

# %%
x_tf = tf.Variable([25, 61, 47])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25, 61, 47], dtype=int32)>
