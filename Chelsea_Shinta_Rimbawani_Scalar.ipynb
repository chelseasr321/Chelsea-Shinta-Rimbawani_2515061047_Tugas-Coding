# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 47

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 47

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
x+y
# Out:
# 94

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.47

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 47.47

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(47)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=47>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(47)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=94>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=94>

# %%
tf_sum.numpy()
# Out:
# np.int32(94)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int32

# %%
tf_float = tf.Variable(47.)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=47.0>

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch as pt

# %%
x_pt = torch.tensor(47)
x_pt
# Out:
# tensor(47)

# %%
x_pt.shape
# Out:
# torch.Size([])
